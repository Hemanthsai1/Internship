# %%
import pandas as pd

# %%
df = pd.read_csv('ratings.csv')

# %%
df.shape
# Out:
# (100836, 4)

# %%
unique_user_ids = df['userId'].nunique()

# %%
unique_user_ids
# Out:
# 610

# %%
df = pd.read_csv('movies.csv')

# %%
movies_df = pd.read_csv('movies.csv')
max_rated_movie_name = movies_df[movies_df['movieId'] == max_rated_movie_id]['title'].values[0]
print("Movie with the maximum number of ratings:", max_rated_movie_name)
# Out:
# Movie with the maximum number of ratings: Forrest Gump (1994)

# %%
matrix_movie_id = movies_df[movies_df['title'] == 'Matrix, The (1999)']['movieId'].values[0]

# %%
tags_df = pd.read_csv('tags.csv')

matrix_tags = tags_df[tags_df['movieId'] == matrix_movie_id]['tag']

print("Tags for 'Matrix, The (1999)':")
print(matrix_tags.unique())
# Out:
# Tags for 'Matrix, The (1999)':
# ['martial arts' 'sci-fi' 'alternate universe' 'philosophy'
#  'post apocalyptic']

# %%
terminator_movie_id = movies_df[movies_df['title'] == 'Terminator 2: Judgment Day (1991)']['movieId'].values[0]

# %%
terminator_ratings = ratings_df[ratings_df['movieId'] == terminator_movie_id]['rating']
average_rating = terminator_ratings.mean()

print("Average rating for 'Terminator 2: Judgment Day (1991)':", average_rating)
# Out:
# Average rating for 'Terminator 2: Judgment Day (1991)': 3.970982142857143

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fight_club_movie_id = movies_df[movies_df['title'] == 'Fight Club (1999)']['movieId'].values[0]
fight_club_ratings = ratings_df[ratings_df['movieId'] == fight_club_movie_id]['rating']

# %%
fight_club_ratings
# Out:
# 192      5.0
# 458      2.0
# 1134     0.5
# 1479     2.5
# 1635     3.5
#         ...
# 95893    5.0
# 96788    4.0
# 97835    5.0
# 99107    5.0
# 99699    5.0
# Name: rating, Length: 218, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(fight_club_ratings, bins=10, kde=True)
plt.title('Distribution of User Ratings for "Fight Club (1999)"')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    average_rating=('rating', 'mean')
).reset_index()

popular_movies_df = grouped_ratings[grouped_ratings['rating_count'] > 50]

merged_df = pd.merge(movies_df, popular_movies_df, on='movieId')

# %%
most_popular_movie = merged_df.loc[merged_df['average_rating'].idxmax()]

print("Most popular movie based on average user ratings:", most_popular_movie['title'])
# Out:
# Most popular movie based on average user ratings: Shawshank Redemption, The (1994)

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    average_rating=('rating', 'mean')
).reset_index()
popular_movies_df = grouped_ratings[grouped_ratings['rating_count'] > 50]
movies_df = pd.read_csv('movies.csv')
merged_df = pd.merge(movies_df, popular_movies_df, on='movieId')

top_5_movies = merged_df.sort_values(by='rating_count', ascending=False).head(5)

# %%
top_5_movies
# Out:
#      movieId                             title                       genres  \
# 61       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 53       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 49       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 99       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 248     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#      rating_count  average_rating
# 61            329        4.164134
# 53            317        4.429022
# 49            307        4.197068
# 99            279        4.161290
# 248           278        4.192446

# %%
top_5_titles = top_5_movies['title'].tolist()
options = [
    'Pulp Fiction (1994)',
    'Bad Boys (1995)',
    'Silence of the Lambs, The (1991)',
    'Matrix, The (1999)'
]
correct_options = [title for title in options if title in top_5_titles]
print("Top 5 popular movies based on number of user ratings:")
print(correct_options)
# Out:
# Top 5 popular movies based on number of user ratings:
# ['Pulp Fiction (1994)', 'Silence of the Lambs, The (1991)', 'Matrix, The (1999)']

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    average_rating=('rating', 'mean')
).reset_index()

popular_movies_df = grouped_ratings[grouped_ratings['rating_count'] > 50]

merged_df = pd.merge(movies_df, popular_movies_df, on='movieId')

# %%
merged_df
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  rating_count  average_rating
# 0    Adventure|Animation|Children|Comedy|Fantasy           215        3.920930
# 1                     Adventure|Children|Fantasy           110        3.431818
# 2                                 Comedy|Romance            52        3.259615
# 3                          Action|Crime|Thriller           102        3.946078
# ...

# %%
sci_fi_movies = merged_df[merged_df['genres'].str.contains('Sci-Fi', case=False, na=False)]
sorted_sci_fi_movies = sci_fi_movies.sort_values(by='rating_count', ascending=False)
third_most_popular_sci_fi = sorted_sci_fi_movies.iloc[2]
print(third_most_popular_sci_fi['title'])
# Out:
# Jurassic Park (1993)

# %%
pip install requests beautifulsoup4 pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\heman\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\heman\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\heman\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\heman\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\heman\AppData\Roaming\Python\Python312\site-packages)

# %%
import pandas as pd
df = pd.read_csv('ratings.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
highest_rated_movie = ratings_df.loc[ratings_df['rating'].idxmax()]
highest_movie_id = highest_rated_movie['movieId']
print(highest_movie_id)
# Out:
# 47.0

# %%
merged_df = pd.merge(movies_df, imdb_ratings_df, on='movieId')

sci_fi_movies = merged_df[merged_df['genres'].str.contains('Sci-Fi', case=False, na=False)]
highest_rated_sci_fi = sci_fi_movies.loc[sci_fi_movies['rating'].idxmax()]

highest_sci_fi_movie_id = highest_rated_sci_fi['movieId']
print("MovieId of the Sci-Fi movie with the highest IMDB rating:", highest_sci_fi_movie_id)
# Out:
# MovieId of the Sci-Fi movie with the highest IMDB rating: 24
